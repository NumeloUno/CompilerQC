# %%
from CompilerQC import *
import pickle
from pathlib import Path
import os
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import pandas as pd
import itertools
import shutil
from visualize_graphs import without_compilation, advanced_plot_df, plot_settings_in_subplot

# %%
# group settings by hand
number = 3
results = []
for idx, name in enumerate(os.listdir(paths.parameters_path / f"run_{number}/dictionaries")):
    print(idx, name)
    results.append(name.split('.')[0])
    
i = 0
for name in os.listdir(paths.parameters_path / f"run_{number}/dictionaries")[i:(i + 1)]:
    print(name)
    with open(paths.parameters_path / f"run_{number}/dictionaries/{name}", "rb") as f:
        new_dicts = pickle.load(f)
        for idx, setting in enumerate(new_dicts):
            print(f"=========={idx}=============")
            for k, v in setting.items():
                print(k, v)
# Out:
# 0 BestSettings3.pkl
# BestSettings3.pkl
# ==========0=============
# with_core False
# ==========1=============
# energy.all_constraints True
# energy.scaling_model LHZ
# ==========2=============
# with_core False
# energy.all_constraints True
# energy.scaling_model LHZ
# ==========3=============
# length_of_node_weight 0.1
# ==========4=============
# length_of_node_weight 0.5
# ==========5=============
# length_of_node_weight 0.9

# %%
df = dict()
for name in results:
    try:
        dataframe = pd.read_csv(f"results_in_csvs/run_{number}/{name}.csv")
#         N = dataframe.N
#         C_3 = N - 2 + (N - 3)
#         C_4 = (N - 3) * (N - 2) / 2 - (N - 3)
#         dataframe['number_of_CNOTs_in_LHZ'] = (6 * C_4 + 4 * C_3)
        dataframe['qubit_ratio'] = dataframe.K / (dataframe.N / 2 * (dataframe.N - 1))
        dataframe['CNOT_ratio'] = dataframe.number_of_CNOTs / dataframe.number_of_CNOTs_in_LHZ
        df.update({name: dataframe})
    except:
        print(f'failed: {name}')
        pass

# %%
problem_folder = 'lhz'
without_compilation(problem_folder)['CNOT_ratio'].plot(marker='8', label='CNOT_ratio')
without_compilation(problem_folder)['qubit_ratio'].plot(marker='8', color='red', label='qubit_ratio')
plt.legend()

# %%
df
# Out:
# {'BestSettings3':        N   K   C  original_C  C_density  number_of_setting  \
#  0     17  42  26          26   0.038462                  5
#  1     12  26  15          15   0.066667                  5
#  2     20  44  25          25   0.120000                  5
#  3     17  42  26          26   0.115385                  5
#  4     16  37  22          22   0.136364                  5
#  ...   ..  ..  ..         ...        ...                ...
#  4858  20  36  17          17   0.352941                  1
#  4859  20  46  27          27   0.185185                  1
#  4860  11  20  10          10   0.100000                  1
#  4861  15  27  13          13   0.307692                  1
#  4862  18  36  19          19   0.210526                  1
#
#        number_of_plaquettes  number_of_3er_plaquettes  \
#  0                       25                         0
#  1                       14                         3
#  2                       22                        12
#  3                       23                         0
#  4                       19                         6
#  ...                    ...                       ...
#  4858                    11                         7
#  4859                    22                        14
#  4860                     9                         6
#  4861                     9                         6
#  4862                    15                         9
#
#        number_of_4er_plaquettes  core  ...   moves number_of_swap_gates  \
#  0                           25  True  ...  252000                    5
#  1                           11  True  ...  156000                    2
#  2                            7  True  ...  264000                    9
#  3                           23  True  ...  252000                    7
#  4                           12  True  ...  222000                    3
#  ...                        ...   ...  ...     ...                  ...
#  4858                         4  True  ...  216000                   11
#  4859                         8  True  ...  276000                   15
#  4860                         3  True  ...  120000                    2
#  4861                         3  True  ...  162000                   12
#  4862                         6  True  ...  216000                    7
#
#        number_of_CNOTs  number_of_CNOTs_in_LHZ  scope_measure  \
#  0                 186                     690          False
#  1                  96                     310          False
#  2                 176                     990          False
#  3                 198                     690          False
#  4                 134                     602          False
#  ...               ...                     ...            ...
#  4858              146                     990          False
#  4859              222                     990          False
#  4860               58                     252          False
#  4861              132                     520          False
#  4862              132                     784          False
#
#        polygon_exponent                                               path  \
#  0                    1  run_3/benchmark_training_set_with_BestSettings...
#  1                    1  run_3/benchmark_training_set_with_BestSettings...
#  2                    1  run_3/benchmark_training_set_with_BestSettings...
#  3                    1  run_3/benchmark_training_set_with_BestSettings...
#  4                    1  run_3/benchmark_training_set_with_BestSettings...
#  ...                ...                                                ...
#  4858                 1  run_3/benchmark_training_set_with_BestSettings...
#  4859                 1  run_3/benchmark_training_set_with_BestSettings...
#  4860                 1  run_3/benchmark_training_set_with_BestSettings...
#  4861                 1  run_3/benchmark_training_set_with_BestSettings...
#  4862                 1  run_3/benchmark_training_set_with_BestSettings...
#
#                                                 complete  qubit_ratio  \
#  0     <bound method Graph.complete of <class 'Compil...     0.308824
#  1     <bound method Graph.complete of <class 'Compil...     0.393939
#  2     <bound method Graph.complete of <class 'Compil...     0.231579
#  3     <bound method Graph.complete of <class 'Compil...     0.308824
#  4     <bound method Graph.complete of <class 'Compil...     0.308333
#  ...                                                 ...          ...
#  4858  <bound method Graph.complete of <class 'Compil...     0.189474
#  4859  <bound method Graph.complete of <class 'Compil...     0.242105
#  4860  <bound method Graph.complete of <class 'Compil...     0.363636
#  4861  <bound method Graph.complete of <class 'Compil...     0.257143
#  4862  <bound method Graph.complete of <class 'Compil...     0.235294
#
#       CNOT_ratio
#  0      0.269565
#  1      0.309677
#  2      0.177778
#  3      0.286957
#  4      0.222591
#  ...         ...
#  4858   0.147475
#  4859   0.224242
#  4860   0.230159
#  4861   0.253846
#  4862   0.168367
#
#  [4863 rows x 23 columns]}

# %%
fig, ax = plt.subplots(figsize=(10, 10))
x_axis, y_axis = 'K', 'CNOT_ratio'
title = 'plaquette rewards'
legend_title = ""
setting_numbers = [0, 1, 2, 3, 4, 5]
setting_names= []#"no reward", r"greedy", "LHZ", "initial energy"]
name = "BestSettings3"
advanced_plot_df(df, name, title, setting_names, setting_numbers, legend_title, x_axis, y_axis, ax)
advanced_plot_df(df, name, title, setting_names, setting_numbers, legend_title, x_axis, y_axis, ax, compare=True)
# Out:
# <AxesSubplot:title={'center':'plaquette rewards'}, xlabel='K', ylabel='#CNOTs $\\frac{compiled}{lhz}$'>
