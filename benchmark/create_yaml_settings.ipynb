# %% [markdown]
# Here you can create the yaml files, which can be benchmarked afterwards.
# Therefore, the default.yaml in the parameters folder is updatet by the dictionary you will specify.
# Dont use _ in file names
#
# Move to folder and run e.g.:find -name "*yaml" | parallel python ../../benchmark_optimization.py --yaml_path={} -b=10 -minN=10 -maxN=10   or run sh ../run_....sh

# %%
# delete all folder 
from pathlib import Path
import shutil
path = Path("parameters/")
for p in path.glob("*"):
    if p.name not in ["run_parameters.sh", "Default"]:
        print(p.name)
        shutil.rmtree(f'parameters/{p.name}', ignore_errors=True)
# Out:
# CoreEnergyWithCore
# CoreEnergy
# CompleteSearchWithCore
# SearchWithCore
# CoreSearch
# Energy
# Search
# EnergyWithCore

# %%
import yaml
from CompilerQC import *

# %%
# open default yaml and update it by default settings
with open(paths.parameters_path / "Default/default.yaml") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
default_update = {
    "with_core": True,
    "random_qbit": True,
    "finite_grid_size": True,
    "padding_finite_grid": 2,
    "repetition_rate_factor": 5,
    "temperature_kirkpatrick_sigma": True,
    "core_temperature_kirkpatrick_sigma": True,
    "core_alpha": 0.99,
    "alpha": 0.99,
    "init_T_by_std": True,
    "core_energy.only_largest_core": True,
    "core_energy.only_squares_in_core": True,
    "core_energy.scaling_model": "MLP",
    "energy.scaling_model": "MLP",
    "core_only_four_cycles_for_ancillas": True,
}
new_config = functions_for_benchmarking.update(config, default_update)

# %%
name = "CoreEnergy"
new_dicts = [
    {"core_energy.scaling_model": "MLP"},
    {"core_energy.scaling_model": "maxC"},
    {"core_energy.scaling_model": "LHZ"},
    {"core_energy.scaling_for_plaq4": 0, "core_energy.scaling_model": None},
    {"core_energy.scaling_for_plaq4": 100, "core_energy.scaling_model": None},
    {"core_energy.scaling_for_plaq4": 1000, "core_energy.scaling_model": None},
    {"core_energy.only_squares_in_core": True},
    {"core_energy.only_squares_in_core": False},
    {"core_energy.spring_energy": True},
    {"core_energy.only_number_of_plaquettes": True},
]
functions_for_benchmarking.create_and_save_settings(name, new_dicts, new_config)
# Out:
# CoreEnergy 0
# CoreEnergy 1
# CoreEnergy 2
# CoreEnergy 3
# CoreEnergy 4
# CoreEnergy 5
# CoreEnergy 6
# CoreEnergy 7
# CoreEnergy 8
# CoreEnergy 9

# %%
name = "CoreSearch"
new_dicts = [
    {"core_n_moves": 10},
    {"core_n_moves": 100},
    {"core_n_moves": 1000},
    {'core_repetition_rate_factor': 2},
    {'core_repetition_rate_factor': 4},
    {'core_repetition_rate_factor': 8},
    {"core_temperature_adaptive": True, "core_temperature_kirkpatrick_sigma": False},
    {"core_temperature_kirkpatrick": True, "core_temperature_kirkpatrick_sigma": False},
    {"core_linear_in_moves": True, "core_temperature_kirkpatrick_sigma": False},
    {"core_temperature_C": True, "core_temperature_kirkpatrick_sigma": False},
    {"core_temperature_linearC": True, "core_temperature_kirkpatrick_sigma": False},
    {"core_cluster_shuffling_probability": 0},
    {"core_cluster_shuffling_probability": 0.1},
    {"core_cluster_shuffling_probability": 0.2},
    {"core_cluster_shuffling_probability": 0.3},
    {"core_only_four_cycles_for_ancillas": False,
     "core_energy.only_squares_in_core": False},
    {"core_only_four_cycles_for_ancillas": True},
    {"core_ancilla_insertion_probability": 0.1, "core_ancilla_deletion_probability": 0},
    {"core_ancilla_insertion_probability": 0.2, "core_ancilla_deletion_probability": 0},
    {"core_ancilla_insertion_probability": 0.4, "core_ancilla_deletion_probability": 0},
    {"core_ancilla_insertion_probability": 0.5, "core_ancilla_deletion_probability": 0},
    {
        "core_ancilla_insertion_probability": 0.1,
        "core_ancilla_deletion_probability": 0.1,
    },
    {
        "core_ancilla_insertion_probability": 0.2,
        "core_ancilla_deletion_probability": 0.2,
    },
    {
        "core_ancilla_insertion_probability": 0.3,
        "core_ancilla_deletion_probability": 0.3,
    },
]
functions_for_benchmarking.create_and_save_settings(name, new_dicts, new_config)
# Out:
# CoreSearch 0
# CoreSearch 1
# CoreSearch 2
# CoreSearch 3
# CoreSearch 4
# CoreSearch 5
# CoreSearch 6
# CoreSearch 7
# CoreSearch 8
# CoreSearch 9
# CoreSearch 10
# CoreSearch 11
# CoreSearch 12
# CoreSearch 13
# CoreSearch 14
# CoreSearch 15
# CoreSearch 16
# CoreSearch 17
# CoreSearch 18
# CoreSearch 19
# CoreSearch 20
# CoreSearch 21
# CoreSearch 22
# CoreSearch 23

# %%
name = "Energy"
new_dicts = [
    {"energy.scaling_model": "MLP"},
    {"energy.scaling_model": "maxC"},
    {"energy.scaling_model": "LHZ"},
    {"energy.scaling_for_plaq3": 0, "energy.scaling_for_plaq4": 0},
    {"energy.scaling_for_plaq3": 100, "energy.scaling_for_plaq4": 100},
    {"energy.scaling_for_plaq3": 1000, "energy.scaling_for_plaq4": 1000},
    {"energy.decay_weight": True, "energy.decay_rate": 1},
    {"energy.decay_weight": True, "energy.decay_rate": 2},
    {"energy.decay_weight": True, "energy.decay_rate": 4},
    {"energy.line": True, "energy.line_exponent": 1},
    {"energy.line": True, "energy.line_exponent": 2},
    {"energy.line": True, "energy.line_exponent": 4},
    {"energy.line": True, "energy.bad_line_penalty": 0},
    {"energy.line": True, "energy.bad_line_penalty": 5},
    {"energy.line": True, "energy.bad_line_penalty": 10},
    {
        "energy.decay_weight": True,
        "energy.decay_rate": 1,
        "energy.line": True,
        "energy.line_exponent": 1,
        "energy.bad_line_penalty": 0,
    },
    {
        "energy.decay_weight": True,
        "energy.decay_rate": 1,
        "energy.line": True,
        "energy.line_exponent": 2,
        "energy.bad_line_penalty": 10,
    },
    {
        "energy.decay_weight": True,
        "energy.decay_rate": 1,
        "energy.line": True,
        "energy.line_exponent": 4,
        "energy.bad_line_penalty": 50,
    },
    {"energy.subset_weight": False},
    {"energy.subset_weight": True},
    {"energy.square_scope": False},
    {"energy.square_scope": True, "scaling_for_plaq3": 1000, "scaling_for_plaq4": 1000},
    {"energy.sparse_density_penalty": False},
    {"energy.sparse_density_penalty": True, "energy.sparse_density_factor": 5},
]
functions_for_benchmarking.create_and_save_settings(f'{name}WithCore', new_dicts,new_config)
new_config_without_core = functions_for_benchmarking.update(new_config, {"with_core": False})
functions_for_benchmarking.create_and_save_settings(name, new_dicts, new_config_without_core)
# Out:
# EnergyWithCore 0
# EnergyWithCore 1
# EnergyWithCore 2
# EnergyWithCore 3
# EnergyWithCore 4
# EnergyWithCore 5
# EnergyWithCore 6
# EnergyWithCore 7
# EnergyWithCore 8
# EnergyWithCore 9
# EnergyWithCore 10
# EnergyWithCore 11
# EnergyWithCore 12
# EnergyWithCore 13
# EnergyWithCore 14
# EnergyWithCore 15
# EnergyWithCore 16
# EnergyWithCore 17
# EnergyWithCore 18
# EnergyWithCore 19
# EnergyWithCore 20
# EnergyWithCore 21
# EnergyWithCore 22
# EnergyWithCore 23
# Energy 0
# Energy 1
# Energy 2
# Energy 3
# Energy 4
# Energy 5
# Energy 6
# Energy 7
# Energy 8
# Energy 9
# Energy 10
# Energy 11
# Energy 12
# Energy 13
# Energy 14
# Energy 15
# Energy 16
# Energy 17
# Energy 18
# Energy 19
# Energy 20
# Energy 21
# Energy 22
# Energy 23

# %%
name = "Search"
new_dicts = [
    {'repetition_rate_factor': 2},
    {'repetition_rate_factor': 4},
    {'repetition_rate_factor': 8},
    {"temperature_adaptive": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_kirkpatrick": True, "temperature_kirkpatrick_sigma": False},
    {"linear_in_moves": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_C": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_linearC": True, "temperature_kirkpatrick_sigma": False},
    {"swap_only_core_qbits_in_line_swaps": False},
    {"swap_only_core_qbits_in_line_swaps": True},
    {"swap_probability": 0},
    {"swap_probability": 0.05},
    {"swap_probability": 0.1},
    {"swap_probability": 0.2},
    {"swap_probability": 0.1, "decay_rate_of_swap_probability": 0.9},
    {"swap_probability": 0.1, "decay_rate_of_swap_probability": 0.6},
    {"swap_probability": 0.1, "decay_rate_of_swap_probability": 0.3},
    {"finite_grid_size": True, "padding_finite_grid": 2},
    {
        "min_plaquette_density_in_softcore": 0.75,
        "shell_time": 50,
        "envelop_shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.75,
        "envelop_shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.85,
        "envelop_shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.95,
        "envelop_shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.75,
        "shell_time": 50,
        "shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.75,
        "shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.85,
        "shell_search": True,
        "finite_grid_size": False,
    },
    {
        "min_plaquette_density_in_softcore": 0.95,
        "shell_search": True,
        "finite_grid_size": False,
    },
    {
        "random_qbit": True,
    },
    {
        "number_of_plaquettes_weight": 0.2,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.4,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.6,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.8,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.2,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.4,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.6,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.8,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.2,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.4,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.6,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.8,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.6,
        "shell_search": True,
        "random_qbit": False,
        "finite_grid_size": False,
    },
    {
        "length_of_node_weight": 0.6,
        "envelop_shell_search": True,
        "random_qbit": False,
        "finite_grid_size": False,
    },
    {
        "qbit_with_same_node": True,
        "random_qbit": False,
    },
    {
        "same_node_coords": True,
        "shell_search": True,
        "random_qbit": True,
        "finite_grid_size": False,
    },
    {
        "same_node_coords": True,
        "envelop_shell_search": True,
        "random_qbit": True,
        "finite_grid_size": False,
    },
]
functions_for_benchmarking.create_and_save_settings(f'{name}WithCore', new_dicts,new_config)
# Out:
# SearchWithCore 0
# SearchWithCore 1
# SearchWithCore 2
# SearchWithCore 3
# SearchWithCore 4
# SearchWithCore 5
# SearchWithCore 6
# SearchWithCore 7
# SearchWithCore 8
# SearchWithCore 9
# SearchWithCore 10
# SearchWithCore 11
# SearchWithCore 12
# SearchWithCore 13
# SearchWithCore 14
# SearchWithCore 15
# SearchWithCore 16
# SearchWithCore 17
# SearchWithCore 18
# SearchWithCore 19
# SearchWithCore 20
# SearchWithCore 21
# SearchWithCore 22
# SearchWithCore 23
# SearchWithCore 24
# SearchWithCore 25
# SearchWithCore 26
# SearchWithCore 27
# SearchWithCore 28
# SearchWithCore 29
# SearchWithCore 30
# SearchWithCore 31
# SearchWithCore 32
# SearchWithCore 33
# SearchWithCore 34
# SearchWithCore 35
# SearchWithCore 36
# SearchWithCore 37
# SearchWithCore 38
# SearchWithCore 39
# SearchWithCore 40
# SearchWithCore 41
# SearchWithCore 42
# SearchWithCore 43

# %%
name = "Search"
new_dicts = [
    {'repetition_rate_factor': 2},
    {'repetition_rate_factor': 4},
    {'repetition_rate_factor': 8},
    {"temperature_adaptive": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_kirkpatrick": True, "temperature_kirkpatrick_sigma": False},
    {"linear_in_moves": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_C": True, "temperature_kirkpatrick_sigma": False},
    {"temperature_linearC": True, "temperature_kirkpatrick_sigma": False},
    {"finite_grid_size": True, "padding_finite_grid": 2},
    {
        "random_qbit": True,
    },
    {
        "number_of_plaquettes_weight": 0.2,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.4,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.6,
        "random_qbit": False,
    },
    {
        "number_of_plaquettes_weight": 0.8,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.2,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.4,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.6,
        "random_qbit": False,
    },
    {
        "sparse_plaquette_density_weight": 0.8,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.2,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.4,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.6,
        "random_qbit": False,
    },
    {
        "length_of_node_weight": 0.8,
        "random_qbit": False,
    },
]
new_config_without_core = functions_for_benchmarking.update(new_config, {"with_core": False})
functions_for_benchmarking.create_and_save_settings(name, new_dicts, new_config_without_core)
# Out:
# Search 0
# Search 1
# Search 2
# Search 3
# Search 4
# Search 5
# Search 6
# Search 7
# Search 8
# Search 9
# Search 10
# Search 11
# Search 12
# Search 13
# Search 14
# Search 15
# Search 16
# Search 17
# Search 18
# Search 19
# Search 20
# Search 21

# %%
name = "CompleteSearch"
import itertools
# open default yaml and update it by default settings
with open(paths.parameters_path / "Default/default.yaml") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
default_update = {
    "with_core": True,
    "random_qbit": True,
    "finite_grid_size": True,
    "padding_finite_grid": 2,
    "repetition_rate_factor": 5,
    "temperature_kirkpatrick_sigma": True,
    "core_temperature_kirkpatrick_sigma": True,
    "core_alpha": 0.99,
    "alpha": 0.99,
    "init_T_by_std": True,
    "core_energy.only_largest_core": True,
    "core_energy.only_squares_in_core": True,
    "core_energy.scaling_model": "MLP",
    "energy.scaling_model": "MLP",
    "core_only_four_cycles_for_ancillas": True,
    "core_repetition_rate_factor": 4,
    "core_cluster_shuffling_probability": 0.1,
    "repetition_rate_factor": 8,
    "swap_probability": 0.1,
    "decay_rate_of_swap_probability": 0.5,
}
new_config = functions_for_benchmarking.update(config, default_update)

individual_settings = [
    [{"core_energy.scaling_for_plaq4": 1000, "core_energy.scaling_model": None},
    {"core_energy.spring_energy": True},
    {"core_energy.only_number_of_plaquettes": True}],

  
    [{"core_ancilla_insertion_probability": 0.1, "core_ancilla_deletion_probability": 0},
    {"core_ancilla_insertion_probability": 0.5, "core_ancilla_deletion_probability": 0}],
    
    [{"energy.scaling_model": "MLP"},
    {"energy.scaling_for_plaq3": 1000, "energy.scaling_for_plaq4": 1000}],
    
    [{},
    {"energy.decay_weight": True, "energy.decay_rate": 1}],
    
    [{},
    {"energy.line": True, "energy.bad_line_penalty": 5, "energy.line_exponent": 2}],



    [{"swap_only_core_qbits_in_line_swaps": False},
    {"swap_only_core_qbits_in_line_swaps": True}],

    [{
        "min_plaquette_density_in_softcore": 0.75,
        "shell_time": 50,
        "envelop_shell_search": True,
        "finite_grid_size": False,
    },

    {
        "min_plaquette_density_in_softcore": 0.95,
        "shell_search": True,
        "finite_grid_size": False,
    },


    {
        "number_of_plaquettes_weight": 0.6,
        "random_qbit": False,
    },


    {
        "length_of_node_weight": 0.6,
        "shell_search": True,
        "random_qbit": False,
        "finite_grid_size": False,
    },
    {
        "length_of_node_weight": 0.6,
        "envelop_shell_search": True,
        "random_qbit": False,
        "finite_grid_size": False,
    }],

]
individual_settings = (list(itertools.product(*individual_settings)))
new_dicts = [{k: v for d in L for k, v in d.items()} for L in individual_settings]
functions_for_benchmarking.create_and_save_settings(f'{name}WithCore', new_dicts,new_config)
# Out:
# CompleteSearchWithCore 0
# CompleteSearchWithCore 1
# CompleteSearchWithCore 2
# CompleteSearchWithCore 3
# CompleteSearchWithCore 4
# CompleteSearchWithCore 5
# CompleteSearchWithCore 6
# CompleteSearchWithCore 7
# CompleteSearchWithCore 8
# CompleteSearchWithCore 9
# CompleteSearchWithCore 10
# CompleteSearchWithCore 11
# CompleteSearchWithCore 12
# CompleteSearchWithCore 13
# CompleteSearchWithCore 14
# CompleteSearchWithCore 15
# CompleteSearchWithCore 16
# CompleteSearchWithCore 17
# CompleteSearchWithCore 18
# CompleteSearchWithCore 19
# CompleteSearchWithCore 20
# CompleteSearchWithCore 21
# CompleteSearchWithCore 22
# CompleteSearchWithCore 23
# CompleteSearchWithCore 24
# CompleteSearchWithCore 25
# CompleteSearchWithCore 26
# CompleteSearchWithCore 27
# CompleteSearchWithCore 28
# CompleteSearchWithCore 29
# CompleteSearchWithCore 30
# CompleteSearchWithCore 31
# CompleteSearchWithCore 32
# CompleteSearchWithCore 33
# CompleteSearchWithCore 34
# CompleteSearchWithCore 35
# CompleteSearchWithCore 36
# CompleteSearchWithCore 37
# CompleteSearchWithCore 38
# CompleteSearchWithCore 39
# CompleteSearchWithCore 40
# CompleteSearchWithCore 41
# CompleteSearchWithCore 42
# CompleteSearchWithCore 43
# CompleteSearchWithCore 44
# CompleteSearchWithCore 45
# CompleteSearchWithCore 46
# CompleteSearchWithCore 47
# CompleteSearchWithCore 48
# CompleteSearchWithCore 49
# CompleteSearchWithCore 50
# CompleteSearchWithCore 51
# CompleteSearchWithCore 52
# CompleteSearchWithCore 53
# CompleteSearchWithCore 54
# CompleteSearchWithCore 55
# CompleteSearchWithCore 56
# CompleteSearchWithCore 57
# CompleteSearchWithCore 58
# CompleteSearchWithCore 59
# CompleteSearchWithCore 60
# CompleteSearchWithCore 61
# CompleteSearchWithCore 62
# CompleteSearchWithCore 63
# CompleteSearchWithCore 64
# CompleteSearchWithCore 65
# CompleteSearchWithCore 66
# CompleteSearchWithCore 67
# CompleteSearchWithCore 68
# CompleteSearchWithCore 69
# CompleteSearchWithCore 70
# CompleteSearchWithCore 71
# CompleteSearchWithCore 72
# CompleteSearchWithCore 73
# CompleteSearchWithCore 74
# CompleteSearchWithCore 75
# CompleteSearchWithCore 76
# CompleteSearchWithCore 77
# CompleteSearchWithCore 78
# CompleteSearchWithCore 79
# CompleteSearchWithCore 80
# CompleteSearchWithCore 81
# CompleteSearchWithCore 82
# CompleteSearchWithCore 83
# CompleteSearchWithCore 84
# CompleteSearchWithCore 85
# CompleteSearchWithCore 86
# CompleteSearchWithCore 87
# CompleteSearchWithCore 88
# CompleteSearchWithCore 89
# CompleteSearchWithCore 90
# CompleteSearchWithCore 91
# CompleteSearchWithCore 92
# CompleteSearchWithCore 93
# CompleteSearchWithCore 94
# CompleteSearchWithCore 95
# CompleteSearchWithCore 96
# CompleteSearchWithCore 97
# CompleteSearchWithCore 98
# CompleteSearchWithCore 99
# CompleteSearchWithCore 100
# CompleteSearchWithCore 101
# CompleteSearchWithCore 102
# CompleteSearchWithCore 103
# CompleteSearchWithCore 104
# CompleteSearchWithCore 105
# CompleteSearchWithCore 106
# CompleteSearchWithCore 107
# CompleteSearchWithCore 108
# CompleteSearchWithCore 109
# CompleteSearchWithCore 110
# CompleteSearchWithCore 111
# CompleteSearchWithCore 112
# CompleteSearchWithCore 113
# CompleteSearchWithCore 114
# CompleteSearchWithCore 115
# CompleteSearchWithCore 116
# CompleteSearchWithCore 117
# CompleteSearchWithCore 118
# CompleteSearchWithCore 119
# CompleteSearchWithCore 120
# CompleteSearchWithCore 121
# CompleteSearchWithCore 122
# CompleteSearchWithCore 123
# CompleteSearchWithCore 124
# CompleteSearchWithCore 125
# CompleteSearchWithCore 126
# CompleteSearchWithCore 127
# CompleteSearchWithCore 128
# CompleteSearchWithCore 129
# CompleteSearchWithCore 130
# CompleteSearchWithCore 131
# CompleteSearchWithCore 132
# CompleteSearchWithCore 133
# CompleteSearchWithCore 134
# CompleteSearchWithCore 135
# CompleteSearchWithCore 136
# CompleteSearchWithCore 137
# CompleteSearchWithCore 138
# CompleteSearchWithCore 139
# CompleteSearchWithCore 140
# CompleteSearchWithCore 141
# CompleteSearchWithCore 142
# CompleteSearchWithCore 143
# CompleteSearchWithCore 144
# CompleteSearchWithCore 145
# CompleteSearchWithCore 146
# CompleteSearchWithCore 147
# CompleteSearchWithCore 148
# CompleteSearchWithCore 149
# CompleteSearchWithCore 150
# CompleteSearchWithCore 151
# CompleteSearchWithCore 152
# CompleteSearchWithCore 153
# CompleteSearchWithCore 154
# CompleteSearchWithCore 155
# CompleteSearchWithCore 156
# CompleteSearchWithCore 157
# CompleteSearchWithCore 158
# CompleteSearchWithCore 159
# CompleteSearchWithCore 160
# CompleteSearchWithCore 161
# CompleteSearchWithCore 162
# CompleteSearchWithCore 163
# CompleteSearchWithCore 164
# CompleteSearchWithCore 165
# CompleteSearchWithCore 166
# CompleteSearchWithCore 167
# CompleteSearchWithCore 168
# CompleteSearchWithCore 169
# CompleteSearchWithCore 170
# CompleteSearchWithCore 171
# CompleteSearchWithCore 172
# CompleteSearchWithCore 173
# CompleteSearchWithCore 174
# CompleteSearchWithCore 175
# CompleteSearchWithCore 176
# CompleteSearchWithCore 177
# CompleteSearchWithCore 178
# CompleteSearchWithCore 179
# CompleteSearchWithCore 180
# CompleteSearchWithCore 181
# CompleteSearchWithCore 182
# CompleteSearchWithCore 183
# CompleteSearchWithCore 184
# CompleteSearchWithCore 185
# CompleteSearchWithCore 186
# CompleteSearchWithCore 187
# CompleteSearchWithCore 188
# CompleteSearchWithCore 189
# CompleteSearchWithCore 190
# CompleteSearchWithCore 191
# CompleteSearchWithCore 192
# CompleteSearchWithCore 193
# CompleteSearchWithCore 194
# CompleteSearchWithCore 195
# CompleteSearchWithCore 196
# CompleteSearchWithCore 197
# CompleteSearchWithCore 198
# CompleteSearchWithCore 199
# CompleteSearchWithCore 200
# CompleteSearchWithCore 201
# CompleteSearchWithCore 202
# CompleteSearchWithCore 203
# CompleteSearchWithCore 204
# CompleteSearchWithCore 205
# CompleteSearchWithCore 206
# CompleteSearchWithCore 207
# CompleteSearchWithCore 208
# CompleteSearchWithCore 209
# CompleteSearchWithCore 210
# CompleteSearchWithCore 211
# CompleteSearchWithCore 212
# CompleteSearchWithCore 213
# CompleteSearchWithCore 214
# CompleteSearchWithCore 215
# CompleteSearchWithCore 216
# CompleteSearchWithCore 217
# CompleteSearchWithCore 218
# CompleteSearchWithCore 219
# CompleteSearchWithCore 220
# CompleteSearchWithCore 221
# CompleteSearchWithCore 222
# CompleteSearchWithCore 223
# CompleteSearchWithCore 224
# CompleteSearchWithCore 225
# CompleteSearchWithCore 226
# CompleteSearchWithCore 227
# CompleteSearchWithCore 228
# CompleteSearchWithCore 229
# CompleteSearchWithCore 230
# CompleteSearchWithCore 231
# CompleteSearchWithCore 232
# CompleteSearchWithCore 233
# CompleteSearchWithCore 234
# CompleteSearchWithCore 235
# CompleteSearchWithCore 236
# CompleteSearchWithCore 237
# CompleteSearchWithCore 238
# CompleteSearchWithCore 239
# CompleteSearchWithCore 240
# CompleteSearchWithCore 241
# CompleteSearchWithCore 242
# CompleteSearchWithCore 243
# CompleteSearchWithCore 244
# CompleteSearchWithCore 245
# CompleteSearchWithCore 246
# CompleteSearchWithCore 247
# CompleteSearchWithCore 248
# CompleteSearchWithCore 249
# CompleteSearchWithCore 250
# CompleteSearchWithCore 251
# CompleteSearchWithCore 252
# CompleteSearchWithCore 253
# CompleteSearchWithCore 254
# CompleteSearchWithCore 255
# CompleteSearchWithCore 256
# CompleteSearchWithCore 257
# CompleteSearchWithCore 258
# CompleteSearchWithCore 259
# CompleteSearchWithCore 260
# CompleteSearchWithCore 261
# CompleteSearchWithCore 262
# CompleteSearchWithCore 263
# CompleteSearchWithCore 264
# CompleteSearchWithCore 265
# CompleteSearchWithCore 266
# CompleteSearchWithCore 267
# CompleteSearchWithCore 268
# CompleteSearchWithCore 269
# CompleteSearchWithCore 270
# CompleteSearchWithCore 271
# CompleteSearchWithCore 272
# CompleteSearchWithCore 273
# CompleteSearchWithCore 274
# CompleteSearchWithCore 275
# CompleteSearchWithCore 276
# CompleteSearchWithCore 277
# CompleteSearchWithCore 278
# CompleteSearchWithCore 279
# CompleteSearchWithCore 280
# CompleteSearchWithCore 281
# CompleteSearchWithCore 282
# CompleteSearchWithCore 283
# CompleteSearchWithCore 284
# CompleteSearchWithCore 285
# CompleteSearchWithCore 286
# CompleteSearchWithCore 287
# CompleteSearchWithCore 288
# CompleteSearchWithCore 289
# CompleteSearchWithCore 290
# CompleteSearchWithCore 291
# CompleteSearchWithCore 292
# CompleteSearchWithCore 293
# CompleteSearchWithCore 294
# CompleteSearchWithCore 295
# CompleteSearchWithCore 296
# CompleteSearchWithCore 297
# CompleteSearchWithCore 298
# CompleteSearchWithCore 299
# CompleteSearchWithCore 300
# CompleteSearchWithCore 301
# CompleteSearchWithCore 302
# CompleteSearchWithCore 303
# CompleteSearchWithCore 304
# CompleteSearchWithCore 305
# CompleteSearchWithCore 306
# CompleteSearchWithCore 307
# CompleteSearchWithCore 308
# CompleteSearchWithCore 309
# CompleteSearchWithCore 310
# CompleteSearchWithCore 311
# CompleteSearchWithCore 312
# CompleteSearchWithCore 313
# CompleteSearchWithCore 314
# CompleteSearchWithCore 315
# CompleteSearchWithCore 316
# CompleteSearchWithCore 317
# CompleteSearchWithCore 318
# CompleteSearchWithCore 319
# CompleteSearchWithCore 320
# CompleteSearchWithCore 321
# CompleteSearchWithCore 322
# CompleteSearchWithCore 323
# CompleteSearchWithCore 324
# CompleteSearchWithCore 325
# CompleteSearchWithCore 326
# CompleteSearchWithCore 327
# CompleteSearchWithCore 328
# CompleteSearchWithCore 329
# CompleteSearchWithCore 330
# CompleteSearchWithCore 331
# CompleteSearchWithCore 332
# CompleteSearchWithCore 333
# CompleteSearchWithCore 334
# CompleteSearchWithCore 335
# CompleteSearchWithCore 336
# CompleteSearchWithCore 337
# CompleteSearchWithCore 338
# CompleteSearchWithCore 339
# CompleteSearchWithCore 340
# CompleteSearchWithCore 341
# CompleteSearchWithCore 342
# CompleteSearchWithCore 343
# CompleteSearchWithCore 344
# CompleteSearchWithCore 345
# CompleteSearchWithCore 346
# CompleteSearchWithCore 347
# CompleteSearchWithCore 348
# CompleteSearchWithCore 349
# CompleteSearchWithCore 350
# CompleteSearchWithCore 351
# CompleteSearchWithCore 352
# CompleteSearchWithCore 353
# CompleteSearchWithCore 354
# CompleteSearchWithCore 355
# CompleteSearchWithCore 356
# CompleteSearchWithCore 357
# CompleteSearchWithCore 358
# CompleteSearchWithCore 359
# CompleteSearchWithCore 360
# CompleteSearchWithCore 361
# CompleteSearchWithCore 362
# CompleteSearchWithCore 363
# CompleteSearchWithCore 364
# CompleteSearchWithCore 365
# CompleteSearchWithCore 366
# CompleteSearchWithCore 367
# CompleteSearchWithCore 368
# CompleteSearchWithCore 369
# CompleteSearchWithCore 370
# CompleteSearchWithCore 371
# CompleteSearchWithCore 372
# CompleteSearchWithCore 373
# CompleteSearchWithCore 374
# CompleteSearchWithCore 375
# CompleteSearchWithCore 376
# CompleteSearchWithCore 377
# CompleteSearchWithCore 378
# CompleteSearchWithCore 379
# CompleteSearchWithCore 380
# CompleteSearchWithCore 381
# CompleteSearchWithCore 382
# CompleteSearchWithCore 383
# CompleteSearchWithCore 384
# CompleteSearchWithCore 385
# CompleteSearchWithCore 386
# CompleteSearchWithCore 387
# CompleteSearchWithCore 388
# CompleteSearchWithCore 389
# CompleteSearchWithCore 390
# CompleteSearchWithCore 391
# CompleteSearchWithCore 392
# CompleteSearchWithCore 393
# CompleteSearchWithCore 394
# CompleteSearchWithCore 395
# CompleteSearchWithCore 396
# CompleteSearchWithCore 397
# CompleteSearchWithCore 398
# CompleteSearchWithCore 399
# CompleteSearchWithCore 400
# CompleteSearchWithCore 401
# CompleteSearchWithCore 402
# CompleteSearchWithCore 403
# CompleteSearchWithCore 404
# CompleteSearchWithCore 405
# CompleteSearchWithCore 406
# CompleteSearchWithCore 407
# CompleteSearchWithCore 408
# CompleteSearchWithCore 409
# CompleteSearchWithCore 410
# CompleteSearchWithCore 411
# CompleteSearchWithCore 412
# CompleteSearchWithCore 413
# CompleteSearchWithCore 414
# CompleteSearchWithCore 415
# CompleteSearchWithCore 416
# CompleteSearchWithCore 417
# CompleteSearchWithCore 418
# CompleteSearchWithCore 419
# CompleteSearchWithCore 420
# CompleteSearchWithCore 421
# CompleteSearchWithCore 422
# CompleteSearchWithCore 423
# CompleteSearchWithCore 424
# CompleteSearchWithCore 425
# CompleteSearchWithCore 426
# CompleteSearchWithCore 427
# CompleteSearchWithCore 428
# CompleteSearchWithCore 429
# CompleteSearchWithCore 430
# CompleteSearchWithCore 431
# CompleteSearchWithCore 432
# CompleteSearchWithCore 433
# CompleteSearchWithCore 434
# CompleteSearchWithCore 435
# CompleteSearchWithCore 436
# CompleteSearchWithCore 437
# CompleteSearchWithCore 438
# CompleteSearchWithCore 439
# CompleteSearchWithCore 440
# CompleteSearchWithCore 441
# CompleteSearchWithCore 442
# CompleteSearchWithCore 443
# CompleteSearchWithCore 444
# CompleteSearchWithCore 445
# CompleteSearchWithCore 446
# CompleteSearchWithCore 447
# CompleteSearchWithCore 448
# CompleteSearchWithCore 449
# CompleteSearchWithCore 450
# CompleteSearchWithCore 451
# CompleteSearchWithCore 452
# CompleteSearchWithCore 453
# CompleteSearchWithCore 454
# CompleteSearchWithCore 455
# CompleteSearchWithCore 456
# CompleteSearchWithCore 457
# CompleteSearchWithCore 458
# CompleteSearchWithCore 459
# CompleteSearchWithCore 460
# CompleteSearchWithCore 461
# CompleteSearchWithCore 462
# CompleteSearchWithCore 463
# CompleteSearchWithCore 464
# CompleteSearchWithCore 465
# CompleteSearchWithCore 466
# CompleteSearchWithCore 467
# CompleteSearchWithCore 468
# CompleteSearchWithCore 469
# CompleteSearchWithCore 470
# CompleteSearchWithCore 471
# CompleteSearchWithCore 472
# CompleteSearchWithCore 473
# CompleteSearchWithCore 474
# CompleteSearchWithCore 475
# CompleteSearchWithCore 476
# CompleteSearchWithCore 477
# CompleteSearchWithCore 478
# CompleteSearchWithCore 479
